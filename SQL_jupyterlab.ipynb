# %%
#Installing SQL module in the notebook

# %%
# !pip install ipython-sql
# Out:
# ...
#   Stored in directory: /Users/youjia/Library/Caches/pip/wheels/80/34/1c/3967380d9676d162cb59513bd9dc862d0584e045a162095606
# Successfully built prettytable
# ...

# %%
#Loading the SQL module

# %%
# %load_ext sql

# %%
#connect to a SQLite database.
#‘Connected: @None' means the connection has been established.

# %%
# %sql sqlite://
# Out:
# 'Connected: @None'

# %%
#create a demo table called EMPLOYEES to showcase the function.

# %%
# %%sql
# CREATE TABLE EMPLOYEE(firstname varchar(50),lastname varchar(50));
# INSERT INTO EMPLOYEE VALUES('Tom','Mitchell');
# INSERT INTO EMPLOYEE VALUES('Jack','Ryan');
# Out:
#  * sqlite://
# Done.
# 1 rows affected.
# 1 rows affected.
# []

# %%
# %sql SELECT * FROM EMPLOYEE;
# Out:
#  * sqlite://
# Done.
# [('Tom', 'Mitchell'), ('Jack', 'Ryan')]

# %%
#making use of the SQL_SAFI database
#download from https://github.com/parulnith/SQL-Interface-within-JupyterLab/blob/master/SQL_SAFI.sqlite

# %%
#Specifying the path of the database  
# %sql sqlite:////Users/youjia/SQL_SAFI.sqlite
# Out:
# 'Connected: @/Users/youjia/SQL_SAFI.sqlite'

# %%
# %sql select * from Crops
# Out:
#    sqlite://
#  * sqlite:////Users/youjia/SQL_SAFI.sqlite
# Done.
# [(1, 1, 1, 1, 'maize', 1),
#  (1, 2, 1, 1, 'maize', 1),
#  (2, 1, 1, 1, 'maize', 1),
#  (2, 2, 1, 1, 'tomatoes', 1),
#  (2, 3, 1, 1, 'vegetable', 1),
#  (3, 1, 1, 1, 'maize', 1),
#  (4, 1, 1, 1, 'maize', 1),
#  (4, 2, 1, 1, 'maize', 1),
#  (4, 3, 1, 1, 'sorghum', 1),
#  (5, 1, 1, 1, 'maize', 1),
#  (5, 2, 1, 1, 'maize', 1),
#  (6, 1, 1, 1, 'maize', 1),
#  (7, 1, 1, 1, 'maize', 1),
#  (7, 2, 1, 1, 'tomatoes', 1),
#  (7, 3, 1, 1, 'beans', 1),
#  (7, 4, 1, 1, 'vegetable', 1),
#  (8, 1, 1, 1, 'maize', 1),
#  (8, 2, 1, 1, 'maize', 1),
#  (9, 1, 1, 1, 'maize', 1),
#  (9, 2, 1, 1, 'tomatoes', 1),
#  (9, 3, 1, 1, 'vegetable', 1),
#  (10, 1, 1, 1, 'maize', 1),
#  (10, 2, 1, 1, 'tomatoes', 1),
#  (11, 1, 1, 1, 'maize', 1),
#  (11, 2, 1, 1, 'maize', 1),
#  (12, 1, 1, 0, 'maize', 0),
#  (12, 2, 1, 1, 'tomatoes', 1),
#  (13, 1, 1, 1, 'maize', 1),
#  (13, 2, 1, 1, 'beans', 1),
#  (13, 3, 1, 1, 'vegetable', 1),
# ...

# %%
# %sql select * from Crops where D_curr_crop = "maize" AND ID <=3;
# Out:
#    sqlite://
#  * sqlite:////Users/youjia/SQL_SAFI.sqlite
# Done.
# [(1, 1, 1, 1, 'maize', 1),
#  (1, 2, 1, 1, 'maize', 1),
#  (2, 1, 1, 1, 'maize', 1),
#  (3, 1, 1, 1, 'maize', 1)]

# %%
#The result can also be converted to a pandas dataframe
result = %sql select * from Crops where D_curr_crop = "maize" AND ID <=3;
dataframe = result.DataFrame()
dataframe.info()
# Out:
#    sqlite://
#  * sqlite:////Users/youjia/SQL_SAFI.sqlite
# Done.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 6 columns):
# Id                      4 non-null int64
# plot_Id                 4 non-null int64
# crop_Id                 4 non-null int64
# D05_times               4 non-null int64
# D_curr_crop             4 non-null object
# D_repeat_times_count    4 non-null int64
# dtypes: int64(5), object(1)
# memory usage: 272.0+ bytes

# %%
#how to install JupyterLab extensions
#To install JupyterLab extensions, you need to have Node.js install.
#run the following commands in the given order
#1
#brew install node #for MacOS users
#or
#conda install -c conda-forge nodejs  
#pip install jupyterlab_sql
#jupyter serverextension enable jupyterlab_sql --py --sys-prefix
#jupyter lab build

# %%
#attention
#To install jupyterlab-sql on versions of JupyterLab pre 1.0, run as follows:

# pip install jupyterlab_sql==0.2.1
# jupyter serverextension enable jupyterlab_sql --py --sys-prefix
# jupyter lab build

# %%
#launch SQL in jupyterlab
#please refer to this URL https://www.datacamp.com/community/tutorials/sql-interface-within-jupyterlab

# %%
# %sql sqlite://
# Out:
# 'Connected: @None'

# %%
# %sql mysql://
# Out:
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys(['sqlite://'])
# No module named 'MySQLdb'
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys(['sqlite://'])

# %%
# !pip install pymysql
# Out:
# ...
#     100% |████████████████████████████████| 51kB 2.0MB/s
# ...

# %%
# !pip install mysql-connector
# Out:
# ...
#     100% |████████████████████████████████| 11.9MB 407kB/s
# ...
#   Stored in directory: /Users/youjia/Library/Caches/pip/wheels/8c/83/a1/f8b6d4bb1bd6208bbde1608bbfa7557504bed9eaf2ecf8c175
# Successfully built mysql-connector
# ...

# %%
import mysql.connector

# %%
import pymysql

connection = pymysql.connect(host='localhost',
                             port=3306,
                             user='youjia',
                             password='zhanglijuan1012',
                             db='mydb',
                             charset='utf8')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-1-af62cb11d451> in <module>
#       6                              password='zhanglijuan1012',
#       7                              db='mydb',
# ----> 8                              charset='utf8')
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/__init__.py in Connect(*args, **kwargs)
#      92     """
#      93     from .connections import Connection
# ---> 94     return Connection(*args, **kwargs)
#      95
#      96 from . import connections as _orig_conn
#
# ...

# %%
import pymysql
def connectdb():
    print('连接到mysql服务器...')
    db = pymysql.connect(
        host="localhost",
        user="root",
        passwd="",
        port=3306,
        db="mydb",
        charset='utf8',
        cursorclass=pymysql.cursors.DictCursor)
    print('连接上了!')
    return db

# %%
connectdb()
# Out:
# 连接到mysql服务器...
# 连接上了!

# %%
import pymysql

connection = pymysql.connect(host='localhost',
                             port=3306,
                             user='root',
                             password='',
                             db='mydb',
                             charset='utf8')
# 使用cursor()方法获取操作游标 
cursor = connection.cursor()
 
# SQL 查询语句
sql = "SELECT * from disney"
try:
   # 执行SQL语句
   cursor.execute(sql)
   # 获取所有记录列表
   results = cursor.fetchall()
   for row in results:
    print(row)
except:
    print ("Error: unable to fetch data")
connection.close()
# Out:
# (2011, 31.0, 69.0, 18.6, 51.2, 11.9, 18.3, 70.2, 11.2, 6.8, 4.1, 6.4, 1.3)
# (2012, 31.0, 69.0, 19.9, 49.6, 12.6, 17.9, 67.5, 11.1, 7.3, 4.2, 7.3, 2.6)
# (2013, 29.8, 70.2, 21.1, 49.5, 12.7, 16.7, 64.6, 11.6, 7.6, 4.0, 8.3, 3.9)
# (2014, 30.0, 70.0, 20.4, 49.5, 13.5, 16.6, 66.2, 11.0, 7.0, 3.8, 7.0, 5.0)
# (2015, 29.5, 70.5, 20.7, 49.6, 13.7, 16.0, 66.7, 10.8, 6.3, 3.4, 6.8, 6.0)
# (2016, 29.7, 70.3, 20.7, 50.1, 13.6, 15.6, 64.7, 10.1, 6.6, 3.2, 6.9, 8.5)
# (2017, 30.4, 69.6, 20.1, 50.9, 13.5, 15.5, 63.6, 10.1, 6.5, 3.3, 6.7, 9.8)
# (2018, 27.7, 72.3, 21.2, 50.7, 12.9, 15.2, 60.8, 10.8, 7.5, 3.4, 7.9, 9.6)
